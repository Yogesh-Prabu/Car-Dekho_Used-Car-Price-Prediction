# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# import files
df = pd.read_csv(r"SBS_Processed_Datasets/03_feature_engineered_output.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8198 entries, 0 to 8197
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                8198 non-null   object
#  1   transmission        8198 non-null   object
#  2   owner_no            8198 non-null   int64
#  3   brand               8198 non-null   object
#  4   model               8198 non-null   object
#  5   model_year          8198 non-null   int64
#  6   variant_name        8198 non-null   object
#  7   price               8198 non-null   float64
#  8   registered_year     8198 non-null   int64
#  9   fuel_type           8198 non-null   object
#  10  kms_driven          8198 non-null   int64
#  11  engine_cc           8198 non-null   int64
#  12  mileage_kmpl        8198 non-null   float64
#  13  car_age             8198 non-null   int64
#  14  mileage_normalized  8198 non-null   float64
#  15  brand_popularity    8198 non-null   float64
#  16  price_per_km        8198 non-null   float64
#  17  age_group           8198 non-null   object
#  18  high_mileage        8198 non-null   int64
#  19  multiple_owners     8198 non-null   int64
# dtypes: float64(5), int64(8), object(7)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
#         city transmission  owner_no    brand               model  model_year  \
# 0  bangalore       manual         3   maruti      maruti celerio        2015
# 1  bangalore       manual         2     ford       ford ecosport        2018
# 2  bangalore       manual         1     tata          tata tiago        2018
# 3  bangalore       manual         1  hyundai       hyundai xcent        2014
# 4  bangalore       manual         1   maruti  maruti sx4 s cross        2015
#
#                variant_name     price  registered_year fuel_type  kms_driven  \
# 0                       vxi  400000.0             2015    petrol      120000
# 1  1.5 petrol titanium bsiv  811000.0             2018    petrol       32706
# 2           1.2 revotron xz  585000.0             2018    petrol       11949
# 3        1.2 kappa s option  462000.0             2014    petrol       17794
# 4             ddis 200 zeta  790000.0             2015    diesel       60000
#
#    engine_cc  mileage_kmpl  car_age  mileage_normalized  brand_popularity  \
# 0        998         23.10        9            2.566667     506751.985890
# 1       1497         17.00        6            2.833333     732400.000000
# 2       1199         23.84        6            3.973333     771862.830588
# 3       1197         19.10       10            1.910000     607984.020283
# 4       1248         23.65        9            2.627778     506751.985890
#
#    price_per_km age_group  high_mileage  multiple_owners
# 0  17316.017316       old             1                1
# 1  47705.882353   mid-age             0                1
# 2  24538.590604   mid-age             1                0
# 3  24188.481675       old             0                0
# 4  33403.805497       old             1                0

# %%
# Check the possible encoding methods
categorical_dtypes = df.select_dtypes(include=['object']).columns.to_list() # take only categorical columns dtypes

enc_recommendation = {
    "column_names" : [],
    "unique_values_count": [],
    "recommended_encoding": []
}

for col in categorical_dtypes:
    unique_count = df[col].nunique()
    enc_recommendation["column_names"].append(col)
    enc_recommendation["unique_values_count"].append(unique_count)

    if unique_count <= 10:
        encoding_type = "one-hot-encoding"
    elif unique_count <= 100:
        encoding_type = "label-encoding"
    else:
        encoding_type = "target-encoding"

    enc_recommendation["recommended_encoding"].append(encoding_type)

encoding_recommended_df = pd.DataFrame(enc_recommendation)

# %%
encoding_recommended_df.sort_values(by=['recommended_encoding'])
# Out:
#    column_names  unique_values_count recommended_encoding
# 2         brand                   33       label-encoding
# 0          city                    6     one-hot-encoding
# 1  transmission                    2     one-hot-encoding
# 5     fuel_type                    5     one-hot-encoding
# 6     age_group                    3     one-hot-encoding
# 3         model                  312      target-encoding
# 4  variant_name                 2100      target-encoding

# %% [markdown]
# ONE HOT ENCODING

# %%
one_hot_encoding_columns = ['city','transmission','fuel_type']  # age-group omitted here cos it shows quantitative relationship (use in label encoding)

df = pd.get_dummies(df,columns=one_hot_encoding_columns,drop_first=True)

# %%
df["age_group"]
# Out:
# 0           old
# 1       mid-age
# 2       mid-age
# 3           old
# 4           old
#          ...
# 8193        new
# 8194        old
# 8195        old
# 8196        old
# 8197    mid-age
# Name: age_group, Length: 8198, dtype: object

# %% [markdown]
# LABEL ENCODING

# %%
#from sklearn.preprocessing import LabelEncoder (used LabelEncoder from this module) 
#AGE
age_group_transform = {
    "new": 0,
    "mid-age": 1,
    "old": 2
}

df["age_group"] = df["age_group"].map(age_group_transform)

#BRAND
label_encoder = LabelEncoder()

df["brand"] = label_encoder.fit_transform(df["brand"])

# %%
# just to know which brand maps which numerical representation we write code below to understand for later use

{i: l for i,l in enumerate(label_encoder.classes_)}
# Out:
# {0: 'audi',
#  1: 'bmw',
#  2: 'chevrolet',
#  3: 'citroen',
#  4: 'datsun',
#  5: 'fiat',
#  6: 'ford',
#  7: 'hindustan motors',
#  8: 'honda',
#  9: 'hyundai',
#  10: 'isuzu',
#  11: 'jaguar',
#  12: 'jeep',
#  13: 'kia',
#  14: 'land rover',
#  15: 'lexus',
#  16: 'mahindra',
#  17: 'mahindra renault',
#  18: 'mahindra ssangyong',
#  19: 'maruti',
#  20: 'mercedes-benz',
#  21: 'mg',
#  22: 'mini',
#  23: 'mitsubishi',
#  24: 'nissan',
#  25: 'opel',
#  26: 'porsche',
#  27: 'renault',
#  28: 'skoda',
#  29: 'tata',
#  30: 'toyota',
#  31: 'volkswagen',
#  32: 'volvo'}

# %%
df.head()
# Out:
#    owner_no  brand               model  model_year              variant_name  \
# 0         3     19      maruti celerio        2015                       vxi
# 1         2      6       ford ecosport        2018  1.5 petrol titanium bsiv
# 2         1     29          tata tiago        2018           1.2 revotron xz
# 3         1      9       hyundai xcent        2014        1.2 kappa s option
# 4         1     19  maruti sx4 s cross        2015             ddis 200 zeta
#
#       price  registered_year  kms_driven  engine_cc  mileage_kmpl  ...  \
# 0  400000.0             2015      120000        998         23.10  ...
# 1  811000.0             2018       32706       1497         17.00  ...
# 2  585000.0             2018       11949       1199         23.84  ...
# 3  462000.0             2014       17794       1197         19.10  ...
# 4  790000.0             2015       60000       1248         23.65  ...
#
#    city_chennai  city_delhi  city_hyderabad  city_jaipur  city_kolkata  \
# 0         False       False           False        False         False
# 1         False       False           False        False         False
# 2         False       False           False        False         False
# 3         False       False           False        False         False
# 4         False       False           False        False         False
#
#    transmission_manual  fuel_type_diesel  fuel_type_electric  fuel_type_lpg  \
# 0                 True             False               False          False
# 1                 True             False               False          False
# 2                 True             False               False          False
# 3                 True             False               False          False
# 4                 True              True               False          False
#
#    fuel_type_petrol
# 0              True
# 1              True
# 2              True
# 3              True
# 4             False
#
# [5 rows x 27 columns]
